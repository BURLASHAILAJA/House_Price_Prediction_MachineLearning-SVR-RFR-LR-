# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Loading Dataset

# %%
data=pd.read_csv("housing.csv")

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# 1        2401        1138         8.3014        NEAR BAY              358500
# 2         496         177         7.2574        NEAR BAY              352100
# 3         558         219         5.6431        NEAR BAY              341300
# 4         565         259         3.8462        NEAR BAY              342200

# %% [markdown]
# # Data_Analysics

# %%
data.shape
# Out:
# (20640, 10)

# %%
data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity', 'median_house_value'],
#       dtype='object')

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
#  9   median_house_value  20640 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
data['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# # Removing Null Values from dataset

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (20433, 10)

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# # Data Visualization

# %%
data_vis=data.drop('ocean_proximity',axis=1)
data_vis
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(data_vis.corr(),annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(data.corr(),
            cmap = 'BrBG',
            fmt = '.2f',
            linewidths = 2,
            annot = True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19672\3681551899.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),
# <Axes: >

# %%
plt.figure(figsize=(16,8))
sns.scatterplot(x='latitude',y='longitude',data=data,hue='median_house_value',palette='Blues_d')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# # Train_Test_Split

# %%
X=data.drop('median_house_value',axis=1)
Y=data['median_house_value']

# %%
X.shape
# Out:
# (20433, 9)

# %%
Y.shape
# Out:
# (20433,)

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
train_data=X_train.join(Y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2518     -122.13     39.74                  20         1401           280.0
# 11511    -118.11     33.73                  32         1258           333.0
# 8557     -118.40     33.93                  35         2217           447.0
# 5778     -118.26     34.15                  14         2981           894.0
# 1161     -121.54     39.51                  33         3585           757.0
# ...          ...       ...                 ...          ...             ...
# 1106     -121.60     39.80                  10         1742           307.0
# 19081    -122.48     38.31                  29         2375           560.0
# 11915    -117.40     33.95                  46         2189           423.0
# 6709     -118.15     34.14                  52          403           117.0
# 2595     -123.74     40.66                  25         2395           431.0
#
# ...

# %% [markdown]
# # One Code Encoding

# %%
train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2518     -122.13     39.74                  20         1401           280.0
# 11511    -118.11     33.73                  32         1258           333.0
# 8557     -118.40     33.93                  35         2217           447.0
# 5778     -118.26     34.15                  14         2981           894.0
# 1161     -121.54     39.51                  33         3585           757.0
# ...          ...       ...                 ...          ...             ...
# 1106     -121.60     39.80                  10         1742           307.0
# 19081    -122.48     38.31                  29         2375           560.0
# 11915    -117.40     33.95                  46         2189           423.0
# 6709     -118.15     34.14                  52          403           117.0
# 2595     -123.74     40.66                  25         2395           431.0
#
# ...

# %%
test_data=X_test.join(Y_test)
test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 356      -122.16     37.76                  36         2781           574.0
# 2192     -119.95     36.80                  30         1233           214.0
# 9161     -118.49     34.42                  23         4166           756.0
# 168      -122.24     37.79                  27         1632           492.0
# 13155    -121.45     36.86                  11         1613           335.0
# ...          ...       ...                 ...          ...             ...
# 6376     -118.03     34.15                  43         1694           283.0
# 13919    -115.85     34.20                  34         3868          1257.0
# 4323     -118.35     34.09                  42         2210           643.0
# 3324     -122.89     38.93                  20         1214           247.0
# 15779    -122.41     37.78                  52          254            72.0
#
# ...

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2518     -122.13     39.74                  20         1401           280.0
# 11511    -118.11     33.73                  32         1258           333.0
# 8557     -118.40     33.93                  35         2217           447.0
# 5778     -118.26     34.15                  14         2981           894.0
# 1161     -121.54     39.51                  33         3585           757.0
# ...          ...       ...                 ...          ...             ...
# 1106     -121.60     39.80                  10         1742           307.0
# 19081    -122.48     38.31                  29         2375           560.0
# 11915    -117.40     33.95                  46         2189           423.0
# 6709     -118.15     34.14                  52          403           117.0
# 2595     -123.74     40.66                  25         2395           431.0
#
# ...

# %%
X_train=X_train.join(pd.get_dummies(X_train.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
X_test=X_test.join(pd.get_dummies(X_test.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2518     -122.13     39.74                  20         1401           280.0
# 11511    -118.11     33.73                  32         1258           333.0
# 8557     -118.40     33.93                  35         2217           447.0
# 5778     -118.26     34.15                  14         2981           894.0
# 1161     -121.54     39.51                  33         3585           757.0
# ...          ...       ...                 ...          ...             ...
# 1106     -121.60     39.80                  10         1742           307.0
# 19081    -122.48     38.31                  29         2375           560.0
# 11915    -117.40     33.95                  46         2189           423.0
# 6709     -118.15     34.14                  52          403           117.0
# 2595     -123.74     40.66                  25         2395           431.0
#
# ...

# %%
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 356      -122.16     37.76                  36         2781           574.0
# 2192     -119.95     36.80                  30         1233           214.0
# 9161     -118.49     34.42                  23         4166           756.0
# 168      -122.24     37.79                  27         1632           492.0
# 13155    -121.45     36.86                  11         1613           335.0
# ...          ...       ...                 ...          ...             ...
# 6376     -118.03     34.15                  43         1694           283.0
# 13919    -115.85     34.20                  34         3868          1257.0
# 4323     -118.35     34.09                  42         2210           643.0
# 3324     -122.89     38.93                  20         1214           247.0
# 15779    -122.41     37.78                  52          254            72.0
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train_sc=sc.fit_transform(X_train)
X_test_sc=sc.transform(X_test)

# %% [markdown]
# # Model_Building

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
from sklearn.ensemble import RandomForestRegressor
RFR=RandomForestRegressor()
RFR.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(X_train,Y_train)
# Out:
# SVR()

# %% [markdown]
# # Evaluating a model

# %%
from sklearn.metrics import mean_absolute_percentage_error
print('Linear Regression Score',LR.score(X_test,Y_test))
print('Random Forest Regressor',RFR.score(X_test,Y_test))
print("SVR",model_SVR.score(X_test,Y_test))
# Out:
# Linear Regression Score 0.6366284604973562
# Random Forest Regression 0.8170864331314132
# SVR -0.04880837282931627

# %%
Y_pred_LR = LR.predict(X_test)
Y_pred_RFR = RFR.predict(X_test)
Y_pred_SVR= model_SVR.predict(X_test)
print("LinearRegression:",mean_absolute_percentage_error(Y_test, Y_pred_LR))
print("RandomForestRegressor:",mean_absolute_percentage_error(Y_test, Y_pred_RFR))
print("SVR:",mean_absolute_percentage_error(Y_test, Y_pred_SVR))
# Out:
# LinearRegression: 0.28984513738018236
# RandomForestRegressor: 0.1809953570913843
# SVR: 0.526304242715711

# %% [markdown]
# # Conclusion

# %% [markdown]
# RandomForestRegressor is best algorithm for our dataset.

# %% [markdown]
# RandomForestRegressor with less mean_absolute_error as 0.18099 and with good score as 0.81708
